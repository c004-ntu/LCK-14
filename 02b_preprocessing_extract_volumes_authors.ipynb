# %% [markdown]
# ## <center> Data Preprocessing </center>

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from tqdm import tqdm

# %%
# %run 00_lib_preprocessing.ipynb
# %run 00_lib_sqlwriter.ipynb

# %% [markdown]
# ### Class Library

# %% [markdown]
# ### Load data

# %%
data_ingestion = DataIngestion_MySQL()
text_preprocessor = TextPreprocessor()

volumes_df, archives_df, articles_df, contents_df, authors_df, authors_articles_df = data_ingestion.load_data()
# Out:
# Table 'volumes' is ready.
# Table 'archives' is ready.
# Table 'articles' is ready.
# Table 'contents' is ready.
# Table 'authors' is ready.
# Table 'authors_articles' is ready.
# [INFO] Loading data files...

# %%
display(volumes_df.head(1))
display(archives_df.head(1))
display(articles_df.head(1))
display(contents_df.head(1))
display(authors_df.head(1))
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#                                          archive_url  \
# 0  https://firstmonday.org/ojs/index.php/fm/issue...
#
#                          volume_number archive_title archive_title_clean  \
# 0  Volume 4, Number 1 - 4 January 1999                              None
#
#   archive_publication_date editor         import_date     status
# 0               1999-01-04        2025-03-12 18:27:25  COMPLETED
#                                          article_url  \
# 0  https://firstmonday.org/ojs/index.php/fm/artic...
#
#                         article_title                 article_title_clean  \
# 0  The Lives and Death of Moore's Law  the lives and death of moore's law
#
#                                      doi article_publication_date  \
# 0  https://doi.org/10.5210/fm.v7i11.1000               2002-11-04
#
#         author author_clean keyword  \
# 0  Ilkka Tuomi  Ilkka Tuomi
#
#                                             abstract  \
# 0   Moore's Law has been an important benchmark f...
#
#                                       abstract_clean  \
# 0   moore's law has been an important benchmark f...
#
#                                          archive_url  \
# 0  https://firstmonday.org/ojs/index.php/fm/issue...
#
#                                          content_url         import_date  \
# 0  https://firstmonday.org/ojs/index.php/fm/artic... 2025-03-13 15:28:07
#
#       status lang                                  abstract_clean_en
# 0  COMPLETED   en   moore's law has been an important benchmark f...
#                                          content_url  \
# 0  https://firstmonday.org/ojs/index.php/fm/artic...
#
#                                           iframe_url  \
# 0  https://firstmonday.org/ojs/index.php/fm/artic...
#
#                                              content  \
# 0  The lives and death of Moore's Law\nMoore’s La...
#
#                                        content_clean lang content_clean_en
# 0  the lives and death of moore's law moore s law...   en
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Extract Volumes

# %%
import re

# Functions to extract special issue and volume name

def extract_volume_name(text):
    # Extracting volume name
    # Sample "Volume 1, Number 1 - 6 May 1996"

    # Extract volume name
    text_split = text.split('Number')
    if len(text_split) > 1:
        volume_name = text_split[0].strip().replace(',', '').replace('.', '')
        # print(f"Volume name: {volume_name}")

    # Extract year information
    year_split = text.split(';')
    # volume_year = re.search(r'\d{4}', year_split)
    if len(year_split)>1:
        volume_year =  year_split[-1]
        # print(f"Year: {volume_year}")
    return volume_name + ', ' + volume_year

def extract_special_issue(text):
    # Extracting special issue
    # Sample "Special Issue #1: Music and the Internet — 4 July 2005"
    text_split = text.split(':')
    if len(text_split) > 1:
        issue_name = text_split[0].strip()
        # print(f"Special Issue: {issue_name}")
    
    # Extract year information
    year_split = text.split(';')
    # issue_year = re.search(r'\d{4}', year_split)
    if len(year_split)>1:
        issue_year =  year_split[-1]
        # print(f"Year: {issue_year}")
    return issue_name + ', ' + issue_year

def split_volume(text):
    parts = text.split(',')
    volume_name = parts[0].strip() if len(parts) > 0 else ""
    volume_year = parts[1].strip() if len(parts) > 1 else ""
    return volume_name, volume_year

# Get unique special issue or volume names
archives_df['unique_volume_number'] = archives_df['volume_number'] + ';' + archives_df['archive_publication_date'].astype(str).str[:4]
archives_df['unique_volume_number'] = archives_df['unique_volume_number'].apply(
    lambda x: extract_volume_name(x) if "Volume" in x else extract_special_issue(x)
)
volume_numbers = archives_df['unique_volume_number']
unique_volume_number = list(set(volume_numbers))

# Create a new DataFrame from the volumes list
volumes_df = pd.DataFrame(unique_volume_number, columns=['volume_number'])
volumes_df['volume_name'] = volumes_df['volume_number'].apply(lambda x: split_volume(x)[0])
volumes_df['volume_year'] = volumes_df['volume_number'].apply(lambda x: split_volume(x)[1])
print("Number of volumes:", len(volumes_df))
display(volumes_df.head(2))

# Write to database
data_ingestion.mysql_writer.insert_volumes(volumes_df)

# Export to Excel
# volumes_df.to_excel('data/volumes.xlsx', index=False)
# print("Volumes has been exported to 'volumes.xlsx'.")
# Out:
# Number of volumes: 39
#             volume_number       volume_name volume_year
# 0         Volume 19, 2014         Volume 19        2014
# 1  Special Issue #8, 2007  Special Issue #8        2007
# Inserted volume_number: Volume 19, 2014
# Inserted volume_number: Special Issue #8, 2007
# Inserted volume_number: Volume 25, 2020
# Inserted volume_number: Volume 22, 2017
# Inserted volume_number: Volume 14, 2009
# Inserted volume_number: Volume 18, 2013
# Inserted volume_number: Volume 29, 2024
# Inserted volume_number: Volume 23, 2018
# Inserted volume_number: Special Issue #7, 2006
# Inserted volume_number: Volume 11, 2006
# Inserted volume_number: Volume 7, 2002
# Inserted volume_number: Special Issue #5, 2006
# Inserted volume_number: Special Issue #1, 2005
# Inserted volume_number: Volume 24, 2019
# Inserted volume_number: Volume 10, 2005
# Inserted volume_number: Volume 8, 2003
# Inserted volume_number: Volume 6, 2001
# Inserted volume_number: Special Issue #6, 2006
# Inserted volume_number: Volume 5, 2000
# Inserted volume_number: Special Issue #3, 2005
# Inserted volume_number: Volume 17, 2012
# Inserted volume_number: Special Issue #4, 2006
# Inserted volume_number: Volume 20, 2015
# Inserted volume_number: Volume 1, 1997
# Inserted volume_number: Volume 2, 1997
# Inserted volume_number: Volume 23, 2017
# Inserted volume_number: Volume 4, 1999
# Inserted volume_number: Volume 13, 2008
# Inserted volume_number: Volume 3, 1998
# Inserted volume_number: Volume 16, 2011
# Inserted volume_number: Volume 9, 2004
# Inserted volume_number: Volume 26, 2021
# Inserted volume_number: Volume 27, 2022
# Inserted volume_number: Volume 28, 2023
# Inserted volume_number: Volume 15, 2010
# Inserted volume_number: Volume 21, 2016
# Inserted volume_number: Volume 12, 2007
# Inserted volume_number: Volume 30, 2025
# Inserted volume_number: Special Issue #2, 2005

# %% [markdown]
# ### Extract Authors

# %%
# Explode Authors

author_article_df = pd.DataFrame()
author_article_df = articles_df[['author','article_url']].copy()
author_article_df.rename(columns={'author': 'author_name'}, inplace=True)
# author_article_df.tail()

# Split authors into lists
author_article_df['author_name'] = author_article_df['author_name'].str.split(', ')

# Explode the authors column into separate rows
author_article_exploded_df = author_article_df.explode('author_name').reset_index(drop=True)

# Clean author
author_article_exploded_df['author_name'] = (author_article_exploded_df['author_name'].str.replace(r'\.', '', regex=True)
                                             .str.replace(r'\s+', ' ', regex=True)  # This replaces multiple spaces with one
                                             .str.strip()  # Remove leading/trailing spaces
                                             )
print(author_article_exploded_df)

# Write to database
data_ingestion.mysql_writer.create_table_authors_articles()
data_ingestion.mysql_writer.insert_authors_articles(author_article_exploded_df)
# Out:
#               author_name                                        article_url
# 0             Ilkka Tuomi  https://firstmonday.org/ojs/index.php/fm/artic...
# 1            Pawel Popiel  https://firstmonday.org/ojs/index.php/fm/artic...
# 2        Mareile Kaufmann  https://firstmonday.org/ojs/index.php/fm/artic...
# 3            Maura Conway  https://firstmonday.org/ojs/index.php/fm/artic...
# 4              Paul Bocij  https://firstmonday.org/ojs/index.php/fm/artic...
# ...                   ...                                                ...
# 4974      Anthony Ralston  https://firstmonday.org/ojs/index.php/fm/artic...
# 4975  Guillermo Hernandez  https://firstmonday.org/ojs/index.php/fm/artic...
# 4976           Miles Dyck  https://firstmonday.org/ojs/index.php/fm/artic...
# 4977    M Derek MacKenzie  https://firstmonday.org/ojs/index.php/fm/artic...
# 4978     Sylvie A Quideau  https://firstmonday.org/ojs/index.php/fm/artic...
#
# [4979 rows x 2 columns]
# Table 'authors_articles' is ready.
# Inserted author_article: Ilkka Tuomi, https://firstmonday.org/ojs/index.php/fm/article/view/1000
# Inserted author_article: Pawel Popiel, https://firstmonday.org/ojs/index.php/fm/article/view/10005
# Inserted author_article: Mareile Kaufmann, https://firstmonday.org/ojs/index.php/fm/article/view/10006
# Inserted author_article: Maura Conway, https://firstmonday.org/ojs/index.php/fm/article/view/1001
# Inserted author_article: Paul Bocij, https://firstmonday.org/ojs/index.php/fm/article/view/1002
# Inserted author_article: Jennifer McLaren, https://firstmonday.org/ojs/index.php/fm/article/view/1003
# Inserted author_article: Gianni Zappala, https://firstmonday.org/ojs/index.php/fm/article/view/1003
# Inserted author_article: Matthew Mitchell, https://firstmonday.org/ojs/index.php/fm/article/view/1004
# Inserted author_article: Han Park, https://firstmonday.org/ojs/index.php/fm/article/view/1005
# Inserted author_article: John Willinsky, https://firstmonday.org/ojs/index.php/fm/article/view/1006
# Inserted author_article: Miriam E Sweeney, https://firstmonday.org/ojs/index.php/fm/article/view/10060
# Inserted author_article: Kelsea Whaley, https://firstmonday.org/ojs/index.php/fm/article/view/10060
# Inserted author_article: Yuchen Zhou, https://firstmonday.org/ojs/index.php/fm/article/view/10062
# Inserted author_article: Mark Dredze, https://firstmonday.org/ojs/index.php/fm/article/view/10062
# Inserted author_article: David A Broniatowski, https://firstmonday.org/ojs/index.php/fm/article/view/10062
# Inserted author_article: William D Adler, https://firstmonday.org/ojs/index.php/fm/article/view/10062
# Inserted author_article: Laurie Putnam, https://firstmonday.org/ojs/index.php/fm/article/view/1007
# Inserted author_article: Stephen Standifird, https://firstmonday.org/ojs/index.php/fm/article/view/1008
# Inserted author_article: Chris Sandvig, https://firstmonday.org/ojs/index.php/fm/article/view/1008
# Inserted author_article: Melissa H Cantrell, https://firstmonday.org/ojs/index.php/fm/article/view/10089
# Inserted author_article: Lauren B Collister, https://firstmonday.org/ojs/index.php/fm/article/view/10089
# Inserted author_article: Paolo G Cordone, https://firstmonday.org/ojs/index.php/fm/article/view/1009
# Inserted author_article:
# Inserted author_article: Peter Wolcott, https://firstmonday.org/ojs/index.php/fm/article/view/997
# Inserted author_article: William McHenry, https://firstmonday.org/ojs/index.php/fm/article/view/997
# Inserted author_article: Igor da Penha Natal, https://firstmonday.org/ojs/index.php/fm/article/view/9971
# Inserted author_article: Luís Correia, https://firstmonday.org/ojs/index.php/fm/article/view/9971
# Inserted author_article: Ana Cristina Garcia, https://firstmonday.org/ojs/index.php/fm/article/view/9971
# Inserted author_article: Leandro Fernandes, https://firstmonday.org/ojs/index.php/fm/article/view/9971
# Inserted author_article: Sandor Vegh, https://firstmonday.org/ojs/index.php/fm/article/view/998
# Inserted author_article: Steve Cisler, https://firstmonday.org/ojs/index.php/fm/article/view/999
# Inserted author_article: Anthony Ralston, https://firstmonday.org/ojs/index.php/fm/article/view/9999
# Inserted author_article: Guillermo Hernandez, https://firstmonday.org/ojs/index.php/fm/article/view/9999
# Inserted author_article: Miles Dyck, https://firstmonday.org/ojs/index.php/fm/article/view/9999
# Inserted author_article: M Derek MacKenzie, https://firstmonday.org/ojs/index.php/fm/article/view/9999
# Inserted author_article: Sylvie A Quideau, https://firstmonday.org/ojs/index.php/fm/article/view/9999

# %% [markdown]
# ### Extract Unique Authors

# %%
import unicodedata

# Create author_df with unique author names only
author_df = pd.DataFrame(
    author_article_exploded_df['author_name']
    .dropna()  # Drop NaNs
    .loc[author_article_exploded_df['author_name'].str.strip() != '']  # Drop empty strings
    .astype(str)  # Convert any floats (NaNs) to 'nan' string
    .apply(lambda x: unicodedata.normalize('NFKD', x).encode('ASCII', 'ignore').decode('utf-8') if x != 'nan' else '')
    .str.replace(r'\s+', ' ', regex=True)  # Replace multiple spaces with one
    .str.strip() # Remove leading/trailing spaces
    .str.title() # To proper case    
    .unique(),
    columns=['author_name']
)

author_df = author_df.sort_values(by='author_name')
print(author_df)
# Out:
#              author_name
# 3597            A Dedeke
# 1853           A Mahmood
# 3196  A Michael Froomkin
# 1180      Aaron Delwiche
# 2447      Aaron K Martin
# ...                  ...
# 504          Zeyno Ustun
# 500        Zilia Estrada
# 3392         Ziqian Song
# 2052   Zizi Papacharissi
# 2749         Zubair Nabi
#
# [3743 rows x 1 columns]

# %%
# Write to database
data_ingestion.mysql_writer.insert_authors(author_df)
# Out:
# Inserted author name: A Dedeke
# Inserted author name: A Mahmood
# Inserted author name: A Michael Froomkin
# Inserted author name: Aaron Delwiche
# Inserted author name: Aaron K Martin
# Inserted author name: Aaron Krowne
# Inserted author name: Aaron Strauss
# Inserted author name: Aaron Trammell
# Inserted author name: Abbe E Forman
# Inserted author name: Abbie Monaco
# Inserted author name: Abby Smith
# Inserted author name: Abdullateef Mohammed
# Inserted author name: Abeba Birhane
# Inserted author name: Abebe Rorissa
# Inserted author name: Abigail Curlew
# Inserted author name: Abigail Moreshead
# Inserted author name: Abigail Sellen
# Inserted author name: Abigail Yao
# Inserted author name: Adam Rifkin
# Inserted author name: Adam Senft
# Inserted author name: Adeline Tay
# Inserted author name: Adem Yilmaz
# Inserted author name: Adeola Abdulateef Elega
# Inserted author name: Adina Gitomer
# Inserted author name: Aditi Biswas
# Inserted author name: Aditya Johri
# Inserted author name: Adriaan Van Der Weel
# Inserted author name: Adrian Barlow
# Inserted author name: Adrian Mccullagh
# Inserted author name: Adriana Iamnitchi
# Inserted author name: Adriana Vivacqua
# Inserted author name: Adrien Joly
# Inserted author name: Adrienne L Massanari
# Inserted author name: Adrienne Russell
# Inserted author name: Adrienne Shaw
# Inserted author name: Agnese Vellar
# Inserted author name: Ahmed Al-Rawi
# Inserted author name: Ahmed El Gody
# Inserted author name: Ahmet Naci Coklar
# Inserted author name: Aidar Zinnatullin
# Inserted author name: Aillkeen Bezerra De Oliveira
# Inserted author name: Aiman Suleiman
# Inserted author name: Aizhan Shomotova
# Inserted author name: Aj Million
# Inserted author name: Ajit Pyati
# Inserted author name: Aki Koivula
# Inserted author name: Alain Puissochet
# Inserted author name: Alain Sandoz
# Inserted author name: Alan Bloom
# Inserted author name: Alan Mandell
# Inserted author name: Alan Peslak
# Inserted author name: Alan R Peslak
# Inserted author name: Alan Tidwell
# Inserted author name: Alasia Datonye Dennis
# Inserted author name: Albert Borgmann
# Inserted author name: Albert Borrero
# Inserted author name: Albert Henderson
# Inserted author name: Albert Meijer
# Inserted author name: Alberto Pepe
# Inserted author name: Alec C Tefertiller
# Inserted author name: Alejandro Allen
# Inserted author name: Aleksander Berentsen
# Inserted author name: Aleksandra Krolak
# Inserted author name: Aleksandra Urman
# Inserted author name: Aleksi Aaltonen
# Inserted author name: Alessandra Maia
# Inserted author name: Alessandro Bessi
# Inserted author name: Alessandro Nuvolari
# Inserted author name: Alessandro R Marcon
# Inserted author name: Alex Beattie
# Inserted author name: Alex Clark
# Inserted author name: Alex J Horton
# Inserted author name: Alex Kotsev
# Inserted author name: Alex Mcauley
# Inserted author name: Alex Ng
# Inserted author name: Alex P Whitworth
# Inserted author name: Alex Reid
# Inserted author name: Alex Soojung-Kim Pang
# Inserted author name: Alexander Gorelik
# Inserted author name: Alexander Halavais
# Inserted author name: Alexander J A M Van Deursen
# Inserted author name: Alexander Lewis
# Inserted author name: Alexander Ly
# Inserted author name: Alexander Mussap
# Inserted author name: Alexander Neish Lugg
# Inserted author name: Alexander P Schouten
# Inserted author name: Alexander Repenning
# Inserted author name: Alexander Van Deursen
# Inserted author name: Alexander Vuylsteke
# Inserted author name: Alexandra Juhasz
# Inserted author name: Alexandra Olteanu
# Inserted author name: Alexandre Abellard
# Inserted author name: Alexandre Diallo
# Inserted author name: Alexandre Monnin
# Inserted author name: Alexandre Pinheiro
# Inserted author name: Alexandros Xenos
# Inserted author name: Alexei Tsinovoi
# Inserted author name: Alexis Schrubbe
# Inserted author name: Alexis Wichowski
# Inserted author name: Ali Ghazinejad
# Inserted author name: Aliandro Lima
# Inserted author name: Alice E Marwick
# Inserted author name: Alice Mcinnes
# Inserted author name: Alice Witt
# Inserted author name: Alicia Gazely
# Inserted author name: Alicja Pawluczuk
# Inserted author name: Aline Da Silva Alves
# Inserted author name: Aline Marques Morais
# Inserted author name: Alireza Nili
# Inserted author name: Alisa Freedman
# Inserted author name: Alison Hicks
# Inserted author name: Alison J Head
# Inserted author name: Alison Le Cornu
# Inserted author name: Alison N Novak
# Inserted author name: Alison Novak
# Inserted author name: Alistair Barros
# Inserted author name: Alistair Black
# Inserted author name: Alistair Edwardes
# Inserted author name: Alistair S Duff
# Inserted author name: Allison Druin
# Inserted author name: Allison Farber
# Inserted author name: Allison Zhang
# Inserted author name: Allyn Radford
# Inserted author name: Alok Vimawala
# Inserted author name: Althea Ml Adey
# Inserted author name: Alwin De Rooij
# Inserted author name: Alyson Gill
# Inserted author name: Alyssa Hasegawa Smith
# Inserted author name: Amanda Clark
# Inserted author name: Amanda Ghosh
# Inserted author name: Amanda Higgins
# Inserted author name: Amanda Raffoul
# Inserted author name: Amanda Spink
# Inserted author name: Ambra Trotto
# Inserted author name: Amelia Anderson
# Inserted author name: Amelia Bryne Potter
# Inserted author name: Amelia Gibson
# Inserted author name: Amelia Johns
# Inserted author name: Amie M Schuck
# Inserted author name: Amir Hossein Ghapanchi
# Inserted author name: Amir Karami
# Inserted author name: Amira Firdaus
# Inserted author name: Amit Rechavi
# Inserted author name: Amit Sheth
# Inserted author name: Ammar Halabi
# Inserted author name: Amparo Lasen
# Inserted author name: Amy A Hasinoff
# Inserted author name: Amy Bruckman
# Inserted author name: Amy G Buhler
# Inserted author name: Amy Gaeta
# Inserted author name: Amy Roth
# Inserted author name: Amy Tracy Wells
# Inserted author name: Amy Winecoff
# Inserted author name: Amy-Louise Watkin
# Inserted author name: An Nguyen
# Inserted author name: Ana Cristina Bicharra Garcia
# Inserted author name: Ana Cristina Garcia
# Inserted author name: Anabel Quan-Haase
# Inserted author name: Anand Padmanabhan
# Inserted author name: Anastasia Salter
# Inserted author name: Anatoliy Gruzd
# Inserted author name: Anders Albrechtslund
# Inserted author name: Anders Geersten
# Inserted author name: Anders Olof Larsson
# Inserted author name: Anderson Almeida Firmino
# Inserted author name: Andi Schwartz
# Inserted author name: Andie Miller
# Inserted author name: Andra Siibak
# Inserted author name: Andre Alves
# Inserted author name: Andre H Caron
# Inserted author name: Andre Oboler
# Inserted author name: Andre Schuller-Zwierlein
# Inserted author name: Andre Sobral
# Inserted author name: Andre Tricot
# Inserted author name: Andrea Ballatore
# Inserted author name: Andrea Bonaccorsi
# Inserted author name: Andrea Ciffolilli
# Inserted author name: Andrea Glorioso
# Inserted author name: Andrea L Guzman
# Inserted author name: Andrea L Kavanaugh
# Inserted author name: Andrea Mcilroy
# Inserted author name: Andrea Pecho-Ninapaytan
# Inserted author name: Andrea Pollio
# Inserted author name: Andrea Wiggins
# Inserted author name: Andreas Birkbak
# Inserted author name: Andreas Harsono
# Inserted author name: Andreas Kitzmann
# Inserted author name: Andreas Kratky
# Inserted author name: Andreas Lenander Gidius
# Inserted author name: Andreas Martin Lisewski
# Inserted author name: Andreas Pomportsis
# Inserted author name: Andreas Veglis
# Inserted author name: Andreea Molnar
# Inserted author name: Andres Guadamuz
# Inserted author name: Andres Rosenberg
# Inserted author name: Andressa Souza Costa
# Inserted author name: Andrew Butterly
# Inserted author name: Andrew Famiglietti
# Inserted author name: Andrew Hampton
# Inserted author name: Andrew Herkovic
# Inserted author name: Andrew Large
# Inserted author name: Andrew M Odlyzko
# Inserted author name: Andrew Mcstay
# Inserted author name: Andrew Michael Duffy
# Inserted author name: Andrew O Baoill
# Inserted author name: Andrew Odlyzko
# Inserted author name: Andrew Rens
# Inserted author name: Andrew Retsema
# Inserted author name: Andrew Schrock
# Inserted author name: Andrew Tsou
# Inserted author name: Andrew Updegrove
# Inserted author name: Andrew W Macdonald
# Inserted author name: Andrew Waller
# Inserted author name: Andrew Whelan
# Inserted author name: Andrew Wilson
# Inserted author name: Andrew Wyckoff
# Inserted author name: Andrey M Elizondo
# Inserted author name: Andy Kirk
# Inserted author name: Andy Uhrich
# Inserted author name: Andy White
# Inserted author name: Andy Williamson
# Inserted author name: Aneeja Guttikonda
# Inserted author name: Aneka Khilnani
# Inserted author name: Anezka Kuzmicova
# Inserted author name: Angela Lewis
# Inserted author name: Angela M Cirucci
# Inserted author name: Angela M Gibson
# Inserted author name: Angela Marzilli
# Inserted author name: Angela Vandenbroek
# Inserted author name: Angelo Spognardi
# Inserted author name: Ania Izabella Rynarzewska
# Inserted author name: Anindita Paul
# Inserted author name: Anis Rahman
# Inserted author name: Anita Howarth
# Inserted author name: Anja Bechmann
# Inserted author name: Anja Nylund Hagen
# Inserted author name: Anker Helms Jrgensen
# Inserted author name: Ankita Raturi
# Inserted author name: Ann Dadich
# Inserted author name: Ann Jaloba
# Inserted author name: Ann Peterson Bishop
# Inserted author name: Ann Russell
# Inserted author name: Ann Weeks
# Inserted author name: Anna Arsenal
# Inserted author name: Anna Bentes
# Inserted author name: Anna Carbery
# Inserted author name: Anna Foka
# Inserted author name: Anna Gladkova
# Inserted author name: Anna Lauren Hoffmann
# Inserted author name: Anna Leander
# Inserted author name: Anna Michalakis
# Inserted author name: Anna Murashova
# Inserted author name: Anna Prashizky
# Inserted author name: Anna Sanmartin Orti
# Inserted author name: Anna Squicciarini
# Inserted author name: Anna Triandafyllidou
# Inserted author name: Anna Wilson
# Inserted author name: Anna Winterbottom
# Inserted author name: Anna Zaitsev
# Inserted author name: Anna Zaytseva
# Inserted author name: Annabell Preuler
# Inserted author name: Annamaria Neag
# Inserted author name: Anne Aula
# Inserted author name: Anne B Napoli
# Inserted author name: Anne Collier
# Inserted author name: Anne Craig
# Inserted author name: Anne Helmond
# Inserted author name: Anne Henderson
# Inserted author name: Anne Hoag
# Inserted author name: Anne Kaun
# Inserted author name: Anne L Washington
# Inserted author name: Anne Mangen
# Inserted author name: Anne Mendenhall
# Inserted author name: Anne R Kenney
# Inserted author name: Anne Rose
# Inserted author name: Anne Shelley
# Inserted author name: Anne-Imelda M Radice
# Inserted author name: Anne-Imelda Radice
# Inserted author name: Anne-Mette Albrechtslund
# Inserted author name: Anne-Mette Bech Albrechtslund
# Inserted author name: Annette N Markham
# Inserted author name: Annie Murray
# Inserted author name: Annika Sehl
# Inserted author name: Anselm Spoerri
# Inserted author name: Anthony Auerbach
# Inserted author name: Anthony Burton
# Inserted author name: Anthony Darrouzet-Nardi
# Inserted author name: Anthony Ferraro
# Inserted author name: Anthony G Wilhelm
# Inserted author name: Anthony Glyn Burton
# Inserted author name: Anthony Limperos
# Inserted author name: Anthony Lincoln
# Inserted author name: Anthony Mccosker
# Inserted author name: Anthony Ralston
# Inserted author name: Anthony-Paul Cooper
# Inserted author name: Antoinette Fage-Butler
# Inserted author name: Anton Laukemper
# Inserted author name: Antonella Esposito
# Inserted author name: Antonio A Casilli
# Inserted author name: Antonio Agustin Garcia
# Inserted author name: Antonio Martella
# Inserted author name: Antony Bryant
# Inserted author name: Antti Silvast
# Inserted author name: Anuj Batta
# Inserted author name: Anwesha Chakraborty
# Inserted author name: Aqdas Malik
# Inserted author name: Aram Sinnreich
# Inserted author name: Aravind Sesagiri Raamkumar
# Inserted author name: Araz Taeihagh
# Inserted author name: Archana Ahlawat
# Inserted author name: Archie Zariski
# Inserted author name: Ard Huizing
# Inserted author name: Arden L Bement Jr
# Inserted author name: Argyro P Karanasiou
# Inserted author name: Ariadna Matamoros-Fernandez
# Inserted author name: Arianna Rossi
# Inserted author name: Ariel Frank
# Inserted author name: Arif Raza
# Inserted author name: Arjen K Lenstra
# Inserted author name: Arkalgud Ramaprasad
# Inserted author name: Arne Flaten
# Inserted author name: Arnout Terpstra
# Inserted author name: Arpan K Kar
# Inserted author name: Arthur Bamford
# Inserted author name: Arthur Sale
# Inserted author name: Arti K Rai
# Inserted author name: Arun Kumar Tripathi
# Inserted author name: Aryn C Karpinski
# Inserted author name: Asbjrn Flstad
# Inserted author name: Ashir Ahmed
# Inserted author name: Ashish Gulhati
# Inserted author name: Ashley Rose Kelly
# Inserted author name: Ashley Stinnett
# Inserted author name: Ashok Deb
# Inserted author name: Asm Kayes
# Inserted author name: Asta Zelenkauskaite
# Inserted author name: Astrid Mager
# Inserted author name: Astrid Van Wesenbeeck
# Inserted author name: Athanasios Kokkos
# Inserted author name: Athanassios P Papakonstantinou
# Inserted author name: Athus Cavalini
# Inserted author name: Attila Marton
# Inserted author name: Audrey Lee-Sung
# Inserted author name: Austin Heap
# Inserted author name: Ava Fatah Gen Schieck
# Inserted author name: Axel Bruns
# Inserted author name: Aybuke Aurum
# Inserted author name: Ayelet Oz
# Inserted author name: Ayisigi Sevdik
# Inserted author name: Aymar Jean Christian
# Inserted author name: Ayoung Yoon
# Inserted author name: Azi Lev-On
# Inserted author name: Aziz Douai
# Inserted author name: Babis Bakopoulos
# Inserted author name: Bakhtiyar Nurumov
# Inserted author name: Balachander Krishnamurthy
# Inserted author name: Baptist Vandersmissen
# Inserted author name: Barath Raghavan
# Inserted author name: Barbara Crump
# Inserted author name: Barbara Fister
# Inserted author name: Barbara Kieslinger
# Inserted author name: Barry Brown
# Inserted author name: Barry Devine
# Inserted author name: Barry Kavanagh
# Inserted author name: Barry Mcmullin
# Inserted author name: Barry Saunders
# Inserted author name: Barry W Cull
# Inserted author name: Barry Wellman
# Inserted author name: Bart Preneel
# Inserted author name: Baruch Shomron
# Inserted author name: Basile Zimmermann
# Inserted author name: Bassem Alhalabi
# Inserted author name: Beate Elvebakk
# Inserted author name: Beatrice Hayes
# Inserted author name: Beck Schaefer
# Inserted author name: Behram Ft Mistree
# Inserted author name: Belinda Oldford
# Inserted author name: Bella Ostromooukhova
# Inserted author name: Ben Collier
# Inserted author name: Ben Egliston
# Inserted author name: Ben Hyde
# Inserted author name: Ben Light
# Inserted author name: Benjamin Bederson
# Inserted author name: Benjamin Brunk
# Inserted author name: Benjamin C W Sittler
# Inserted author name: Benjamin Horne
# Inserted author name: Benjamin Loveluck
# Inserted author name: Benjamin Mako Hill
# Inserted author name: Benjamin Peters
# Inserted author name: Benno Luthiger
# Inserted author name: Benny Bornfeld
# Inserted author name: Bente Kalsnes
# Inserted author name: Bernard Hibbitts
# Inserted author name: Bernard J Jansen
# Inserted author name: Bernard Reilly
# Inserted author name: Bernardo A Huberman
# Inserted author name: Bernardo Huberman
# Inserted author name: Bernd Lutterbeck
# Inserted author name: Bernhard Rieder
# Inserted author name: Bernie Hogan
# Inserted author name: Bert Verhulst
# Inserted author name: Bertram C Bruce
# Inserted author name: Bertrum H Macdonald
# Inserted author name: Besiki Stvilia
# Inserted author name: Beth Archibald Tang
# Inserted author name: Beth Driscoll
# Inserted author name: Beth Kolko
# Inserted author name: Beth Noveck
# Inserted author name: Beth Robertson
# Inserted author name: Beth Sandore
# Inserted author name: Beth St Jean
# Inserted author name: Bethany Berard
# Inserted author name: Bethany Hipple Walters
# Inserted author name: Bethany Rose Lamont
# Inserted author name: Bettina Mitru
# Inserted author name: Beverly Lynch
# Inserted author name: Beverly Ray
# Inserted author name: Bhakti Gala
# Inserted author name: Bharat Mehra
# Inserted author name: Bhushan Patwardhan
# Inserted author name: Bibi Van Den Berg
# Inserted author name: Bikalpa Neupane
# Inserted author name: Bill Barnett
# Inserted author name: Bill Helling
# Inserted author name: Bill Hilf
# Inserted author name: Bill Tomlinson
# Inserted author name: Bin Wang
# Inserted author name: Bindi Shah
# Inserted author name: Birgit Penzenstadler
# Inserted author name: Birgit Verbeure
# Inserted author name: Bjorn Hermans
# Inserted author name: Bjorn Nansen
# Inserted author name: Bjrn Nansen
# Inserted author name: Bo Xie
# Inserted author name: Bob Fleck
# Inserted author name: Bob Jolliffe
# Inserted author name: Bob Williams
# Inserted author name: Bonnie A Nardi
# Inserted author name: Bonnie Nardi
# Inserted author name: Bonnie Ruberg
# Inserted author name: Boon Heng Teh
# Inserted author name: Boris Galitsky
# Inserted author name: Boyce Tankersley
# Inserted author name: Brad De Long
# Inserted author name: Brad Love
# Inserted author name: Bradely H Hemminger
# Inserted author name: Bradley Carl Freeman
# Inserted author name: Bradley Wade Bishop
# Inserted author name: Bran Knowles
# Inserted author name: Brandon Niezgoda
# Inserted author name: Brandon Storlie
# Inserted author name: Bree Mcewan
# Inserted author name: Brenda Chawner
# Inserted author name: Brenda L Killingsworth
# Inserted author name: Brendan Luyt
# Inserted author name: Brendan O'Connor
# Inserted author name: Brendan O'Hallarn
# Inserted author name: Brendan Scott
# Inserted author name: Brent Jesiek
# Inserted author name: Brent Kilbourn
# Inserted author name: Brett A Bumgarner
# Inserted author name: Brett Bobley
# Inserted author name: Brett M Frischmann
# Inserted author name: Brian C Britt
# Inserted author name: Brian C O'Connor
# Inserted author name: Brian Carolan
# Inserted author name: Brian Carver
# Inserted author name: Brian Detlor
# Inserted author name: Brian G Kennelly
# Inserted author name: Brian Gorman
# Inserted author name: Brian Harrington
# Inserted author name: Brian Kahin
# Inserted author name: Brian M Watson
# Inserted author name: Brian Martin
# Inserted author name: Brian Murphy
# Inserted author name: Brian O'Neill
# Inserted author name: Brian Owen
# Inserted author name: Brian Still
# Inserted author name: Brian Wentz
# Inserted author name: Brian Whitacre
# Inserted author name: Brian Whitworth
# Inserted author name: Brian Yecies
# Inserted author name: Brigitte Jordan
# Inserted author name: Britt Paris
# Inserted author name: Brittany Brannon
# Inserted author name: Brittany White
# Inserted author name: Brooke Foucault Welles
# Inserted author name: Bruce Cole
# Inserted author name: Bruce Fulton
# Inserted author name: Bruce L Mann
# Inserted author name: Bruce Mason
# Inserted author name: Bruce Perens
# Inserted author name: Bruce Schneier
# Inserted author name: Bruno Giussani
# Inserted author name: Bruno Gonzalez-Cacheda
# Inserted author name: Bryan R Routledge
# Inserted author name: Bryan Semaan
# Inserted author name: Bryce Clayton Newell
# Inserted author name: Bryn Loban
# Inserted author name: Bunty Avieson
# Inserted author name: Burton Speakman
# Inserted author name: Byoung-Jo J Kim
# Inserted author name: Byron Reeves
# Inserted author name: C Pascu
# Inserted author name: C Sean Burns
# Inserted author name: Caifan Du
# Inserted author name: Cait Mckinney
# Inserted author name: Caitlin Ring Carlson
# Inserted author name: Caleb T Carr
# Inserted author name: Caleb Wayne Lack
# Inserted author name: Callum Jones
# Inserted author name: Calvert Jones
# Inserted author name: Calvin Liang
# Inserted author name: Cameron Buckner
# Inserted author name: Camilla Fulton
# Inserted author name: Camilla Hallgren
# Inserted author name: Camilla Soelseth
# Inserted author name: Camille Dickson-Deane
# Inserted author name: Camille Johnson-Yale
# Inserted author name: Camille Jones
# Inserted author name: Candice Vander Weerdt
# Inserted author name: Caren Crowley
# Inserted author name: Cari Dorey
# Inserted author name: Carla B Wright
# Inserted author name: Carles Roca-Cuberes
# Inserted author name: Carlos A Scolari
# Inserted author name: Carlos Castillo
# Inserted author name: Carlos Lopez Carrasco
# Inserted author name: Carlos Lopezosa
# Inserted author name: Carlos Rodriguez
# Inserted author name: Carme Ferre-Pavia
# Inserted author name: Carmen Gould
# Inserted author name: Carmen Marincu
# Inserted author name: Carmen Rios
# Inserted author name: Carola Jungwirth
# Inserted author name: Carole Groleau
# Inserted author name: Carolina Are
# Inserted author name: Carolina Sacramento
# Inserted author name: Caroline Bassett
# Inserted author name: Caroline Dombrowski
# Inserted author name: Caroline Elizabeth Dadas
# Inserted author name: Caroline Haythornthwaite
# Inserted author name: Caroline Hummels
# Inserted author name: Caroline J Tolbert
# Inserted author name: Caroline Lego Munoz
# Inserted author name: Caroline Spiranovic
# Inserted author name: Caroline Whippey
# Inserted author name: Carolyn Elerding
# Inserted author name: Carolyn Hank
# Inserted author name: Carolyn Willard
# Inserted author name: Carolyne Lee
# Inserted author name: Carrie Buchanan
# Inserted author name: Carrie Karsgaard
# Inserted author name: Carsten Stage
# Inserted author name: Carter Jernigan
# Inserted author name: Casey Odonnell
# Inserted author name: Casey Stepaniuk
# Inserted author name: Cassidy R Sugimoto
# Inserted author name: Cassidy Sugimoto
# Inserted author name: Cat Jones
# Inserted author name: Catarina Delgado
# Inserted author name: Cate Watson
# Inserted author name: Catherine Bouko
# Inserted author name: Catherine Brooks
# Inserted author name: Catherine F Brooks
# Inserted author name: Catherine Luther
# Inserted author name: Catherine Sack
# Inserted author name: Cathy Hartman
# Inserted author name: Cathy Mccartney
# Inserted author name: Cathy N Norton
# Inserted author name: Cecile Meadel
# Inserted author name: Celina Kacperski
# Inserted author name: Celso Cancela Outeda
# Inserted author name: Cem Cuhadar
# Inserted author name: Cesare Silla
# Inserted author name: Chad P Abel-Kops
# Inserted author name: Chai Wen Teoh
# Inserted author name: Chandell Gosse
# Inserted author name: Chandra Prabha
# Inserted author name: Charles Bazerman
# Inserted author name: Charles Curran
# Inserted author name: Charles F Thomas
# Inserted author name: Charles Lyons
# Inserted author name: Charles M Schweik
# Inserted author name: Charles Mcclure
# Inserted author name: Charles R Mcclure
# Inserted author name: Charles Schweik
# Inserted author name: Charles Swett
# Inserted author name: Charles Wagner
# Inserted author name: Charlotte Tschider
# Inserted author name: Chei Sian Lee
# Inserted author name: Chen Jinan
# Inserted author name: Cheshta Arora
# Inserted author name: Chia-Ning Chiang
# Inserted author name: Chih-Hui Lai
# Inserted author name: Chiou-Pirng Wang
# Inserted author name: Chirag Shah
# Inserted author name: Chong Zhang
# Inserted author name: Chow Kay
# Inserted author name: Chris Bronk
# Inserted author name: Chris Fullwood
# Inserted author name: Chris Hagar
# Inserted author name: Chris Hartman
# Inserted author name: Chris Holland
# Inserted author name: Chris Jay Hoofnagle
# Inserted author name: Chris Joseph
# Inserted author name: Chris Marsden
# Inserted author name: Chris May
# Inserted author name: Chris Miller
# Inserted author name: Chris Moore
# Inserted author name: Chris Rasch
# Inserted author name: Chris Sandvig
# Inserted author name: Chris Sturm
# Inserted author name: Chris Tomer
# Inserted author name: Chris Trainor
# Inserted author name: Chris Werry
# Inserted author name: Chrisa Tsinaraki
# Inserted author name: Christian F Rostbll
# Inserted author name: Christian Pieter Hoffmann
# Inserted author name: Christian Remy
# Inserted author name: Christian Schwarzenegger
# Inserted author name: Christian Stegbauer
# Inserted author name: Christiana Kumalasari
# Inserted author name: Christiane Paul
# Inserted author name: Christina Aperjis
# Inserted author name: Christina Buckles
# Inserted author name: Christina Dunbar-Hester
# Inserted author name: Christina Harrington
# Inserted author name: Christina Neumayer
# Inserted author name: Christina Preston
# Inserted author name: Christina Raasch
# Inserted author name: Christina Struik
# Inserted author name: Christine L Borgman
# Inserted author name: Christine M Kodama
# Inserted author name: Christine Maher
# Inserted author name: Christine Maxwell
# Inserted author name: Christine Simon
# Inserted author name: Christine Sowa Lepird
# Inserted author name: Christine T Wolf
# Inserted author name: Christine Wolfe
# Inserted author name: Christoph Lutz
# Inserted author name: Christopher Abad
# Inserted author name: Christopher B Browne
# Inserted author name: Christopher Ball
# Inserted author name: Christopher Cronin
# Inserted author name: Christopher Cyr
# Inserted author name: Christopher D F Honig
# Inserted author name: Christopher Df Honig
# Inserted author name: Christopher Dunn
# Inserted author name: Christopher Hunter
# Inserted author name: Christopher J Carpenter
# Inserted author name: Christopher J Mackie
# Inserted author name: Christopher J Persaud
# Inserted author name: Christopher Lueg
# Inserted author name: Christopher M Kelty
# Inserted author name: Christopher Mascaro
# Inserted author name: Christopher May
# Inserted author name: Christopher O'Neill
# Inserted author name: Christopher Paul
# Inserted author name: Christopher Rowe
# Inserted author name: Christopher Soghoian
# Inserted author name: Christopher Vardeman
# Inserted author name: Christopher Whyte
# Inserted author name: Chuck Tryon
# Inserted author name: Chun Wei Choo
# Inserted author name: Chuying Huo
# Inserted author name: Cielo Saucedo
# Inserted author name: Cindy Tekobbe
# Inserted author name: Claes Thoren
# Inserted author name: Claire Dormann
# Inserted author name: Claire Harrison
# Inserted author name: Claire Jones
# Inserted author name: Clara Centeno
# Inserted author name: Clara Llebot
# Inserted author name: Clarissa Ai Ling Lee
# Inserted author name: Clark Hogan-Taylor
# Inserted author name: Claudette Bradley
# Inserted author name: Claudia Herbst
# Inserted author name: Claudio De Souza Baptista
# Inserted author name: Clem Herman
# Inserted author name: Clemens Apprich
# Inserted author name: Cliff Barney
# Inserted author name: Clifford Lynch
# Inserted author name: Clifford Tatum
# Inserted author name: Clifton Evers
# Inserted author name: Clint Brooks
# Inserted author name: Cole Stratton
# Inserted author name: Colette Ormonde
# Inserted author name: Colin Ackerman
# Inserted author name: Colin Allen
# Inserted author name: Colin Bennett
# Inserted author name: Colin Salter
# Inserted author name: Colleen A Reilly
# Inserted author name: Colleen Theisen
# Inserted author name: Connie Moss
# Inserted author name: Connie Wolf
# Inserted author name: Connor Grant
# Inserted author name: Coppelie Cocq
# Inserted author name: Coreen Walsh
# Inserted author name: Corinna Di Gennaro
# Inserted author name: Corinne Jones
# Inserted author name: Cornelius Herstatt
# Inserted author name: Cornelius Puschmann
# Inserted author name: Corrina Perrone
# Inserted author name: Cory P Knobel
# Inserted author name: Courtney Lawrence Douglass
# Inserted author name: Craig A Depken
# Inserted author name: Craig H Rowland
# Inserted author name: Cristian Berrio-Zapata
# Inserted author name: Cristian Jimenez Ruiz
# Inserted author name: Cristiana Gonzalez
# Inserted author name: Cristina Castillo Rodriguez
# Inserted author name: Cristina Rosales Sanchez
# Inserted author name: Cristina Rossi
# Inserted author name: Critical Friends Of Technology Cft
# Inserted author name: Crystal Abidin
# Inserted author name: Crystal Lee
# Inserted author name: Cuihua Shen
# Inserted author name: Cynthia Breazeal
# Inserted author name: Cynthia Kurtz
# Inserted author name: Cynthia Requardt
# Inserted author name: Cynthia Smith
# Inserted author name: Cynthia Stout
# Inserted author name: D E Wittkower
# Inserted author name: D Fox Harrell
# Inserted author name: D Osimo
# Inserted author name: D Yvette Wohn
# Inserted author name: Dal Yong Jin
# Inserted author name: Dalaki Jym Livingston
# Inserted author name: Dale Leorke
# Inserted author name: Damian J Ruck
# Inserted author name: Damian Trilling
# Inserted author name: Dan Handley
# Inserted author name: Dan Jurafsky
# Inserted author name: Dan L Burk
# Inserted author name: Dan Marmion
# Inserted author name: Dan Perkel
# Inserted author name: Dan Richards
# Inserted author name: Dan Stokols
# Inserted author name: Dan Sultanescu
# Inserted author name: Dana Ott
# Inserted author name: Dana Reijerkerk
# Inserted author name: Danah Boyd
# Inserted author name: Dandara Magalhaes
# Inserted author name: Daniel Angus
# Inserted author name: Daniel Ashton
# Inserted author name: Daniel Calderon
# Inserted author name: Daniel Carter
# Inserted author name: Daniel Catalan-Matamoros
# Inserted author name: Daniel Cockayne
# Inserted author name: Daniel Cohen
# Inserted author name: Daniel De Zeeuw
# Inserted author name: Daniel Everts
# Inserted author name: Daniel Faltesek
# Inserted author name: Daniel Gelaw
# Inserted author name: Daniel J Cohen
# Inserted author name: Daniel Jackson
# Inserted author name: Daniel Kreiss
# Inserted author name: Daniel M Downs
# Inserted author name: Daniel M Romero
# Inserted author name: Daniel Nylen
# Inserted author name: Daniel P Dolan
# Inserted author name: Daniel Pargman
# Inserted author name: Daniel Poulin
# Inserted author name: Daniel R Thomas
# Inserted author name: Daniel Rios
# Inserted author name: Daniel Romero
# Inserted author name: Daniel Rough
# Inserted author name: Daniel Scain Farenzena
# Inserted author name: Daniel Taninecz Miller
# Inserted author name: Daniel Tracy
# Inserted author name: Daniel Trottier
# Inserted author name: Daniela Kaiser
# Inserted author name: Daniela Pisoiu
# Inserted author name: Daniela Stockmann
# Inserted author name: Daniela Van Geenen
# Inserted author name: Daniella Dipaola
# Inserted author name: Danielle Hoover
# Inserted author name: Danielle K Kilgo
# Inserted author name: Danielle Sanches
# Inserted author name: Danni Liao
# Inserted author name: Danny A Kingsley
# Inserted author name: Danny Hughes
# Inserted author name: Danny Yee
# Inserted author name: Daphne Ruth Raban
# Inserted author name: Daren C Brabham
# Inserted author name: Darren Linvill
# Inserted author name: Darryl Mead
# Inserted author name: Darryl Woodford
# Inserted author name: Davi Oliveira Serrano De Andrade
# Inserted author name: David A Banks
# Inserted author name: David A Broniatowski
# Inserted author name: David A Huffaker
# Inserted author name: David A Wiley
# Inserted author name: David Adelman
# Inserted author name: David Altheide
# Inserted author name: David B Bills
# Inserted author name: David B Liroff
# Inserted author name: David Bach
# Inserted author name: David Bamman
# Inserted author name: David Beer
# Inserted author name: David Blakesley
# Inserted author name: David Carter
# Inserted author name: David Chapman
# Inserted author name: David Clark
# Inserted author name: David Condon
# Inserted author name: David F Noble
# Inserted author name: David Gehring
# Inserted author name: David George Glance
# Inserted author name: David Glance
# Inserted author name: David Huffaker
# Inserted author name: David Igliozzi
# Inserted author name: David J Solomon
# Inserted author name: David J Yates
# Inserted author name: David Kamerer
# Inserted author name: David Kreps
# Inserted author name: David L Tulloch
# Inserted author name: David Lancashire
# Inserted author name: David Lindsey
# Inserted author name: David M Berry
# Inserted author name: David M Levy
# Inserted author name: David M Nichols
# Inserted author name: David Marshall
# Inserted author name: David Mathieu
# Inserted author name: David Matthew Gopilan
# Inserted author name: David Mcgowan
# Inserted author name: David Michael Douglas
# Inserted author name: David Nemer
# Inserted author name: David Nichols
# Inserted author name: David Osimo
# Inserted author name: David Pettersen
# Inserted author name: David Phillips
# Inserted author name: David Post
# Inserted author name: David R Chesnutt
# Inserted author name: David R Johnson
# Inserted author name: David R Sewell
# Inserted author name: David Resnick
# Inserted author name: David Robertshaw
# Inserted author name: David Robins
# Inserted author name: David Ronfeldt
# Inserted author name: David Russell
# Inserted author name: David S White
# Inserted author name: David Silver
# Inserted author name: David Smahel
# Inserted author name: David Solomon
# Inserted author name: David Stuart
# Inserted author name: David Sward
# Inserted author name: David Valle-Cruz
# Inserted author name: David Vieglais
# Inserted author name: David W Lightfoot
# Inserted author name: David Wagner
# Inserted author name: David Wedaman
# Inserted author name: David Wiley
# Inserted author name: David Wong
# Inserted author name: David Wu
# Inserted author name: David Zager
# Inserted author name: David Zeitlyn
# Inserted author name: Davide Beraldo
# Inserted author name: Davis Eisape
# Inserted author name: Dawit Demissie
# Inserted author name: Dawn Watling
# Inserted author name: Deanna B Marcum
# Inserted author name: Deb Aikat
# Inserted author name: Debarun Sarkar
# Inserted author name: Debbie Campbell
# Inserted author name: Debora J Halbert
# Inserted author name: Debora Shaw
# Inserted author name: Deborah K Morrison
# Inserted author name: Deborah S Garson
# Inserted author name: Debra Guenther
# Inserted author name: Debra J Richardson
# Inserted author name: Declan J Graham
# Inserted author name: Deen Freelon
# Inserted author name: Delia Dumitrica
# Inserted author name: Denis Newman-Griffis
# Inserted author name: Denise A Smith
# Inserted author name: Denise Koufougiannakis
# Inserted author name: Denise Meredyth
# Inserted author name: Denise Russo
# Inserted author name: Denise Wood
# Inserted author name: Dennis Deicke
# Inserted author name: Dennis M Wilkinson
# Inserted author name: Derek Keats
# Inserted author name: Derek Lackaff
# Inserted author name: Desiree Joosten-Ten Brinke
# Inserted author name: Devendra Dilip Potnis
# Inserted author name: Devendra Potnis
# Inserted author name: Di Wu
# Inserted author name: Diana Helton Rennels
# Inserted author name: Diana Tseng
# Inserted author name: Diane Gurman
# Inserted author name: Diane Harley
# Inserted author name: Diane I Hillman
# Inserted author name: Diane M Zorich
# Inserted author name: Diane Wahl
# Inserted author name: Didem Ozkul
# Inserted author name: Dietrich Kappe
# Inserted author name: Dima Saber
# Inserted author name: Dimitrios Reppas
# Inserted author name: Dina Abdel-Mageed
# Inserted author name: Dion Dennis
# Inserted author name: Dirk Lewandowski
# Inserted author name: Dirk Nicolas Wagner
# Inserted author name: Dirk Spennemann
# Inserted author name: Ditte Laursen
# Inserted author name: Dmitri Williams
# Inserted author name: Dmitry Muravyov
# Inserted author name: Dominic O'Donnell
# Inserted author name: Dominique Boullier
# Inserted author name: Dominique Guellec
# Inserted author name: Dominique Marshall
# Inserted author name: Don Hamerly
# Inserted author name: Don King
# Inserted author name: Don Lewicki
# Inserted author name: Don Turnbull
# Inserted author name: Donald J Patterson
# Inserted author name: Donald J Waters
# Inserted author name: Donghee Yvette Wohn
# Inserted author name: Donghwa Chung
# Inserted author name: Donna Chu
# Inserted author name: Doran A Tucker
# Inserted author name: Dorit Geifman
# Inserted author name: Dorothy M Persson
# Inserted author name: Doug Brent
# Inserted author name: Douglas A Galbi
# Inserted author name: Douglas Holland
# Inserted author name: Douglas Kocher
# Inserted author name: Drazen Pantic
# Inserted author name: Dung (June) Pham
# Inserted author name: Duong Dang
# Inserted author name: Duygu Ozsoy
# Inserted author name: Dylan Eric Wittkower
# Inserted author name: Earvin Charles B Cabalquinto
# Inserted author name: Eben Moglen
# Inserted author name: Ed Dawson
# Inserted author name: Ed Gerck
# Inserted author name: Ed Valauskas
# Inserted author name: Edgar A Ruvalcaba-Gomez
# Inserted author name: Edgar Gomez Cruz
# Inserted author name: Edna Miola
# Inserted author name: Eduarda Ferreira
# Inserted author name: Eduardo Villanueva
# Inserted author name: Eduardo Villanueva Mansilla
# Inserted author name: Eduardo Villanueva-Mansilla
# Inserted author name: Edward A Galloway
# Inserted author name: Edward Castronova
# Inserted author name: Edward J Valauskas
# Inserted author name: Edward Schneider
# Inserted author name: Edward Valauskas
# Inserted author name: Eedan Amit-Danhi
# Inserted author name: Eef Masson
# Inserted author name: Eian More
# Inserted author name: Elaine M Huang
# Inserted author name: Elaine Peterson
# Inserted author name: Elaine Tavares
# Inserted author name: Elan Lee
# Inserted author name: Eleanor Lockley
# Inserted author name: Eleanor Sandry
# Inserted author name: Elena Feinstein
# Inserted author name: Elena Roglia
# Inserted author name: Elena Vartanova
# Inserted author name: Eli Skogerb
# Inserted author name: Eliane Pinheiro Capra
# Inserted author name: Elina Eriksson
# Inserted author name: Elinor Carmi
# Inserted author name: Elisabeth Montemurro
# Inserted author name: Elisaveta Gourova
# Inserted author name: Elise Jensen
# Inserted author name: Elisha Lim
# Inserted author name: Elissa M Redmiles
# Inserted author name: Elizabeth Anne Roodhouse
# Inserted author name: Elizabeth Broun
# Inserted author name: Elizabeth Davison
# Inserted author name: Elizabeth Ellcessor
# Inserted author name: Elizabeth J Decoster
# Inserted author name: Elizabeth Larson
# Inserted author name: Elizabeth Losh
# Inserted author name: Elizabeth Murphy
# Inserted author name: Elizabeth Smith
# Inserted author name: Elizabeth W Brown
# Inserted author name: Elizaveta Popova
# Inserted author name: Elizeu Santos-Neto
# Inserted author name: Elke Greifeneder
# Inserted author name: Ellen Detlefsen
# Inserted author name: Ellen Freeman
# Inserted author name: Ellen J Kabat Lensch
# Inserted author name: Elliot Panek
# Inserted author name: Elliott Wood
# Inserted author name: Elmie Nekmat
# Inserted author name: Elsy Lao
# Inserted author name: Elyse Adler
# Inserted author name: Emerich Daroya
# Inserted author name: Emile P Torres
# Inserted author name: Emilia Barna
# Inserted author name: Emiliano Trere
# Inserted author name: Emilie Rene-Veronneau
# Inserted author name: Emilija Jokubauskaite
# Inserted author name: Emilio Ferrara
# Inserted author name: Emily Chen
# Inserted author name: Emily Heinlen
# Inserted author name: Emily Hong
# Inserted author name: Emily Raine
# Inserted author name: Emily Therese Heinlen
# Inserted author name: Emily Van Der Nagel
# Inserted author name: Emir A Mohammed
# Inserted author name: Emma Baulch
# Inserted author name: Emma Dahlin
# Inserted author name: Emma Frieh
# Inserted author name: Emma Leigh Waldron
# Inserted author name: Emma Stuart
# Inserted author name: Emnet Tafesse
# Inserted author name: Enoch Peserico
# Inserted author name: Enrique Orduna-Malea
# Inserted author name: Erhardt Graeff
# Inserted author name: Eric Gordon
# Inserted author name: Eric J Reed
# Inserted author name: Eric Jardine
# Inserted author name: Eric Kerr
# Inserted author name: Eric Lease Morgan
# Inserted author name: Eric M Meyers
# Inserted author name: Eric Ps Baumer
# Inserted author name: Eric Raymond
# Inserted author name: Eric S Raymond
# Inserted author name: Eric Shook
# Inserted author name: Eric Snodgrass
# Inserted author name: Eric Williams
# Inserted author name: Erica Defrain
# Inserted author name: Erica Johnson
# Inserted author name: Erik Borra
# Inserted author name: Erik Choi
# Inserted author name: Erik Christiansen
# Inserted author name: Erik G Christiansen
# Inserted author name: Erik Hekman
# Inserted author name: Erik P Bucy
# Inserted author name: Erik W Black
# Inserted author name: Erika Fernandez-Gomez
# Inserted author name: Erika Pearson
# Inserted author name: Erika Solis
# Inserted author name: Erin M Sumner
# Inserted author name: Erkki Sutinen
# Inserted author name: Erkun Zhang
# Inserted author name: Ersin Dincelli
# Inserted author name: Eryn N Bostwick
# Inserted author name: Erzsebet Angster
# Inserted author name: Esteban Morales
# Inserted author name: Ester Aguirre
# Inserted author name: Ester Ferreira Da Silva
# Inserted author name: Ester Van Laar
# Inserted author name: Esther Dyson
# Inserted author name: Esther Milne
# Inserted author name: Esther Mwema
# Inserted author name: Esther Van Zimmeren
# Inserted author name: Esther Weltevrede
# Inserted author name: Estrid Srensen
# Inserted author name: Eszter Hargittai
# Inserted author name: Ethan Berman
# Inserted author name: Ethan Katsh
# Inserted author name: Ethan R Plaut
# Inserted author name: Ethan Zuckerman
# Inserted author name: Etienne Pelaprat
# Inserted author name: Eugene Kim
# Inserted author name: Eun-Kyung Na
# Inserted author name: Eurico Matos
# Inserted author name: Evagelia Avraam
# Inserted author name: Evandro Ziggiatti Monteiro
# Inserted author name: Eve Forrest
# Inserted author name: Eve Mitletonkelly
# Inserted author name: Eve Richardson
# Inserted author name: Evelien D'Heer
# Inserted author name: Evelina Liliequist
# Inserted author name: Evelyn Daniel
# Inserted author name: Everett Wetchler
# Inserted author name: Eytan Adar
# Inserted author name: Eytan Bakshy
# Inserted author name: Eyyup Akbulut
# Inserted author name: Ezra Ondari-Okemwa
# Inserted author name: F Maxwell Harper
# Inserted author name: F Ted Tschang
# Inserted author name: F Xavier Olleros
# Inserted author name: Fabio Creta
# Inserted author name: Fabio Gouveia
# Inserted author name: Fabio Malini
# Inserted author name: Fabricio Benevenuto
# Inserted author name: Fan Dong
# Inserted author name: Fandy Tjiptono
# Inserted author name: Fang Wu
# Inserted author name: Farida Vis
# Inserted author name: Farinaz Basmechi
# Inserted author name: Fatemeh Bagherian
# Inserted author name: Fatima Aziz
# Inserted author name: Fatima Espinoza Vasquez
# Inserted author name: Fauzan Eka Kusuma
# Inserted author name: Fay Durrant
# Inserted author name: Faye Vowell
# Inserted author name: Federica Fornaciari
# Inserted author name: Federica Giovanella
# Inserted author name: Federica Timeto
# Inserted author name: Federico Cinus
# Inserted author name: Federico Iannacci
# Inserted author name: Federico Scrinzi
# Inserted author name: Fei Gao
# Inserted author name: Fei Shen
# Inserted author name: Felipe Cardoso
# Inserted author name: Felipe Soares
# Inserted author name: Felix Garten
# Inserted author name: Felix Lippe
# Inserted author name: Felix Oloyede
# Inserted author name: Felix Stalder
# Inserted author name: Fenwick Mckelvey
# Inserted author name: Fernanda Freire
# Inserted author name: Fernanda Pires
# Inserted author name: Fernando Diaz
# Inserted author name: Fernando Severo
# Inserted author name: Ferris Shahrestani
# Inserted author name: Fidele Vlavo
# Inserted author name: Fikile Mazibuko
# Inserted author name: Filippo Menczer
# Inserted author name: Filippo Trevisan
# Inserted author name: Finn Arup Nielsen
# Inserted author name: Finn Brunton
# Inserted author name: Finn Hansen
# Inserted author name: Fiona Murray
# Inserted author name: Floor Fiers
# Inserted author name: Florante Cruz
# Inserted author name: Florence Nowak
# Inserted author name: Florencia Garcia-Rapp
# Inserted author name: Frances Corry
# Inserted author name: Frances Dilauro
# Inserted author name: Francesca Musiani
# Inserted author name: Francesca Romana Seganti
# Inserted author name: Francesca Tenca
# Inserted author name: Francesco Grisolia
# Inserted author name: Francine Barone
# Inserted author name: Francis Dalisay
# Inserted author name: Francisco Javier Ruiz Del Olmo
# Inserted author name: Francisco Paulo Jamil Almeida Marques
# Inserted author name: Francisco Paulo Jamil Marques
# Inserted author name: Francisco Segado-Boj
# Inserted author name: Francisco Seoane Perez
# Inserted author name: Franco Chiaraluce
# Inserted author name: Francois Luong
# Inserted author name: Francoise Dauce
# Inserted author name: Frank Bannister
# Inserted author name: Frank P Albritton Jr
# Inserted author name: Frank Pasquale
# Inserted author name: Frank Rennie
# Inserted author name: Frank Vetere
# Inserted author name: Franklin Nii Amankwah Yartey
# Inserted author name: Frauke Lehmann
# Inserted author name: Frauke Zeller
# Inserted author name: Frazer Woodhead
# Inserted author name: Fred Evans
# Inserted author name: Fred Fonseca
# Inserted author name: Fred Gault
# Inserted author name: Fred Schiff
# Inserted author name: Frederick Bennett
# Inserted author name: Frederick Douzet
# Inserted author name: Frederick Schiff
# Inserted author name: Frederik Lesage
# Inserted author name: Fredrik Stiernstedt
# Inserted author name: Frida Siekkinen
# Inserted author name: Funda Kivran-Swaine
# Inserted author name: G Anthony Giannoumis
# Inserted author name: G Sayeed Choudhury
# Inserted author name: G Scott Aikens
# Inserted author name: G Turlea
# Inserted author name: G Zachary
# Inserted author name: Gabe Ignatow
# Inserted author name: Gabriela Da Silva Zago
# Inserted author name: Gabriele De Seta
# Inserted author name: Gabriele Ruiu
# Inserted author name: Gabriella Kazai
# Inserted author name: Gabrielle Beacken
# Inserted author name: Gabrielle Grow
# Inserted author name: Gaby David
# Inserted author name: Gagan Deep Sharma
# Inserted author name: Gagan Jindal
# Inserted author name: Gail Matthews-Denatale
# Inserted author name: Gal Yavetz
# Inserted author name: Ganaele Langlois
# Inserted author name: Ganesan Vaidyanathan
# Inserted author name: Gary Burnett
# Inserted author name: Gary Hepburn
# Inserted author name: Gary Klass
# Inserted author name: Gaston Becerra
# Inserted author name: Gavin Clarkson
# Inserted author name: Gavin S Clarkson
# Inserted author name: Geert Lovink
# Inserted author name: Geertrui Van Overwalle
# Inserted author name: Gejun Huang
# Inserted author name: Gemma Martinez Fernandez
# Inserted author name: Gemma Newlands
# Inserted author name: Gene Hettel
# Inserted author name: Gene Hyde
# Inserted author name: Geoff Freed
# Inserted author name: Geoffrey C Bowker
# Inserted author name: Geoffry Taubman
# Inserted author name: Georg Buss
# Inserted author name: Georg Singer
# Inserted author name: George Cole
# Inserted author name: George Dafermos
# Inserted author name: George E Marsh
# Inserted author name: George H Buck
# Inserted author name: George Kerscher
# Inserted author name: George N Dafermos
# Inserted author name: George Sylvie
# Inserted author name: George Tsourvakas
# Inserted author name: George Veletsianos
# Inserted author name: Georgia Gaden
# Inserted author name: Gerard Carat
# Inserted author name: Gerard Gill
# Inserted author name: Gerard Goggin
# Inserted author name: Gerard J Nauwelaerts
# Inserted author name: Gerd Paul
# Inserted author name: Gergo Jozsef Szollosi
# Inserted author name: Gerhard Fischer
# Inserted author name: Gerry Wall
# Inserted author name: Gert Matthijs
# Inserted author name: Geyong Min
# Inserted author name: Giacomo Poderi
# Inserted author name: Giada Marino
# Inserted author name: Gianni Zappala
# Inserted author name: Gideon Greenspan
# Inserted author name: Gilad Ravid
# Inserted author name: Giles Moss
# Inserted author name: Giliam De Valk
# Inserted author name: Gill Stoker
# Inserted author name: Gilles Sahut
# Inserted author name: Gillian Byrne
# Inserted author name: Gina M Masullo
# Inserted author name: Giorgia Aiello
# Inserted author name: Giota Alevizou
# Inserted author name: Giovan Francesco Lanzara
# Inserted author name: Giovanni Comarela
# Inserted author name: Giovanni Luca Ciampaglia
# Inserted author name: Gisela Gil-Egui
# Inserted author name: Giselle Beiguelman
# Inserted author name: Gisle Hannemyr
# Inserted author name: Gitte Balling
# Inserted author name: Gitte Stald
# Inserted author name: Giuliana Cucinelli
# Inserted author name: Giulio Corsi
# Inserted author name: Giuseppe Lugano
# Inserted author name: Giyoung Park
# Inserted author name: Glen Farrelly
# Inserted author name: Glendal Robinson
# Inserted author name: Glenn Dalgarno
# Inserted author name: Glenn Muschert
# Inserted author name: Glenn Pass
# Inserted author name: Glenn Russell
# Inserted author name: Gloria M Boone
# Inserted author name: Gloria Mark
# Inserted author name: Gloria Rohmann
# Inserted author name: Goran Muric
# Inserted author name: Gordon Schmidt
# Inserted author name: Gowtham Bellala
# Inserted author name: Grace M Jackson-Brown
# Inserted author name: Gracen Brilmyer
# Inserted author name: Graeme Baxter Bell
# Inserted author name: Graeme Johanson
# Inserted author name: Graham Cormode
# Inserted author name: Graham Jensen
# Inserted author name: Graham Low
# Inserted author name: Grant Blank
# Inserted author name: Grant Schoenebeck
# Inserted author name: Greg Elmer
# Inserted author name: Greg Perreault
# Inserted author name: Greg Riccardi
# Inserted author name: Greg Stinson
# Inserted author name: Greg Wiseman
# Inserted author name: Gregory Byshenk
# Inserted author name: Gregory C Unruh
# Inserted author name: Gregory D Saxton
# Inserted author name: Gregory Gondwe
# Inserted author name: Gregory Reece-Smith
# ...
# Inserted author name: Stefan Hrastinski
# Inserted author name: Stefan Koch
# Inserted author name: Stefania Milan
# Inserted author name: Stefania Vicari
# Inserted author name: Stefanie Haustein
# Inserted author name: Stefano Cresci
# Inserted author name: Stefano De Paoli
# Inserted author name: Stefano Tognazzi
# Inserted author name: Stefany Zambrano-Zuta
# Inserted author name: Steffen Kruger
# Inserted author name: Stein Monteiro
# Inserted author name: Stella Page
# Inserted author name: Stephanie Birdsall
# Inserted author name: Stephanie C Haas
# Inserted author name: Stephanie Geise
# Inserted author name: Stephanie Holliman
# Inserted author name: Stephanie J Coopman
# Inserted author name: Stephanie Khoury
# Inserted author name: Stephanie M Reich
# Inserted author name: Stephanie Van Dellen
# Inserted author name: Stephanie Vie
# Inserted author name: Stephanie Vincent
# Inserted author name: Stephen Baker
# Inserted author name: Stephen Dann
# Inserted author name: Stephen Downes
# Inserted author name: Stephen E Delong
# Inserted author name: Stephen Mccreery
# Inserted author name: Stephen Molldrem
# Inserted author name: Stephen Shapiro
# Inserted author name: Stephen Standifird
# Inserted author name: Stephen Viller
# Inserted author name: Stephen Warren
# Inserted author name: Stephen Whyte
# Inserted author name: Stephen Wilson
# Inserted author name: Sterling D Quinn
# Inserted author name: Steve Cisler
# Inserted author name: Steve Dietz
# Inserted author name: Steve Eskow
# Inserted author name: Steve Jonathan Huckle
# Inserted author name: Steve Jones
# Inserted author name: Steve Mann
# Inserted author name: Steve Mcshane
# Inserted author name: Steve Midgley
# Inserted author name: Steve Mitchell
# Inserted author name: Steve Weber
# Inserted author name: Steve Whittaker
# Inserted author name: Steven Corbett
# Inserted author name: Steven Foster
# Inserted author name: Steven Gamble
# Inserted author name: Steven J Jackson
# Inserted author name: Steven L Hensen
# Inserted author name: Steven Lloyd Wilson
# Inserted author name: Steven M Friedman
# Inserted author name: Steven S Chong
# Inserted author name: Steven Sams
# Inserted author name: Steven Sheffield
# Inserted author name: Steven W Sowards
# Inserted author name: Steven Weber
# Inserted author name: Stijn Peeters
# Inserted author name: Stimulate Six Group
# Inserted author name: Stina Teilmann-Lock
# Inserted author name: Stine Lomborg
# Inserted author name: Stribor Kuric
# Inserted author name: Stuart Bender
# Inserted author name: Stuart Frazier Allen
# Inserted author name: Stuart Glogoff
# Inserted author name: Stuart Henshall
# Inserted author name: Stuart J Thorson
# Inserted author name: Stuart Peters
# Inserted author name: Stuart Weibel
# Inserted author name: Su-Euk Park
# Inserted author name: Suay Melisa Ozkula
# Inserted author name: Sue Thomas
# Inserted author name: Suen De Andrade E Silva
# Inserted author name: Sumanth Gopinath
# Inserted author name: Summer Ash
# Inserted author name: Sun Kyong Lee
# Inserted author name: Sun-Ha Hong
# Inserted author name: Susan B Barnes
# Inserted author name: Susan B Kretchmer
# Inserted author name: Susan C Herring
# Inserted author name: Susan Gerhart
# Inserted author name: Susan Keith
# Inserted author name: Susan Landau
# Inserted author name: Susan M Chard
# Inserted author name: Susan Mcdaniel
# Inserted author name: Susan S Lukesh
# Inserted author name: Susanna Paasonen
# Inserted author name: Sushil Sharma
# Inserted author name: Suvarsha Minj
# Inserted author name: Suzanne De Castell
# Inserted author name: Sven Engesser
# Inserted author name: Sven Schade
# Inserted author name: Svend Larsen
# Inserted author name: Svenja Schafer
# Inserted author name: Sybil Brigham Mcshane
# Inserted author name: Sylvia Buntkokhuis
# Inserted author name: Sylvia M Chan-Olmsted
# Inserted author name: Sylvie A Quideau
# Inserted author name: T L Cowan
# Inserted author name: Taemin Kim Park
# Inserted author name: Taimour Ahmed
# Inserted author name: Tali Aharoni
# Inserted author name: Tama Leaver
# Inserted author name: Tamar Ashuri
# Inserted author name: Tamar Israeli
# Inserted author name: Tamara Kohn
# Inserted author name: Tamara Shepherd
# Inserted author name: Tamara Sumner
# Inserted author name: Tamas Tofalvy
# Inserted author name: Tan Liying
# Inserted author name: Tanaporn Charoenthansakul
# Inserted author name: Tanvi Banerjee
# Inserted author name: Tara Brabazon
# Inserted author name: Tara Tobin Cataldo
# Inserted author name: Tarun Sharma
# Inserted author name: Tatiana Karabchuk
# Inserted author name: Tatiana Pontes
# Inserted author name: Tatsuo Tanaka
# Inserted author name: Tayfun Tanyeri
# Inserted author name: Taylor Blose
# Inserted author name: Taylor Boas
# Inserted author name: Taylor C Boas
# Inserted author name: Taylor Reynolds
# Inserted author name: Ted Byfield
# Inserted author name: Ted Daniels
# Inserted author name: Ted Friedman
# Inserted author name: Ted M Coopman
# Inserted author name: Ted Nellen
# Inserted author name: Teemu Leinonen
# Inserted author name: Teemu Maenpaa
# Inserted author name: Teemu Mikkonen
# Inserted author name: Tena Mcqueen
# Inserted author name: Tendai Makasi
# Inserted author name: Teo Keipi
# Inserted author name: Teodor Mitew
# Inserted author name: Tere Vaden
# Inserted author name: Teresa Cerratto Pargman
# Inserted author name: Teresa Cerratto-Pargman
# Inserted author name: Teresa Morley
# Inserted author name: Terje Hillesund
# Inserted author name: Tero Uusitalo
# Inserted author name: Terri Towner
# Inserted author name: Terrie Lynn Thompson
# Inserted author name: Terry Anderson
# Inserted author name: Terry Maxwell
# Inserted author name: Terry T Ahmed
# Inserted author name: Tessa Spencer
# Inserted author name: Teun Lucassen
# Inserted author name: Thais Sarda
# Inserted author name: The Archives Students
# Inserted author name: Theo Rohle
# Inserted author name: Theodora Sutton
# Inserted author name: Theodore Book
# Inserted author name: Theodore Kerr
# Inserted author name: Theodoros Tzouramanis
# Inserted author name: Theresa Schilhab
# Inserted author name: Therese Jennissen
# Inserted author name: Thessa Jensen
# Inserted author name: Thiago Dos Santos
# Inserted author name: Thomas Abraham
# Inserted author name: Thomas Apperley
# Inserted author name: Thomas Boeschoten
# Inserted author name: Thomas Chesney
# Inserted author name: Thomas E Jevec
# Inserted author name: Thomas J Johnson
# Inserted author name: Thomas Kasakowskij
# Inserted author name: Thomas M Malaby
# Inserted author name: Thomas Mueller
# Inserted author name: Thomas Nicolai
# Inserted author name: Thomas P Mackey
# Inserted author name: Thomas Plotkowiak
# Inserted author name: Thomas Poell
# Inserted author name: Thomas Sugimoto
# Inserted author name: Thurasamy Ramayah
# Inserted author name: Thuy Dinh
# Inserted author name: Tiago Rodrigues
# Inserted author name: Tianshi Zhao
# Inserted author name: Tibor Beke
# Inserted author name: Tibor Koltay
# Inserted author name: Tibor Rosko
# Inserted author name: Tien Tran
# Inserted author name: Tiina Malinen
# Inserted author name: Tim Dilauro
# Inserted author name: Tim Eisler
# Inserted author name: Tim Highfield
# Inserted author name: Tim Jordan
# Inserted author name: Tim Miller
# Inserted author name: Tim Schneider
# Inserted author name: Tim Simcoe
# Inserted author name: Tim Venables
# Inserted author name: Tim Weninger
# Inserted author name: Tim Ziaukas
# Inserted author name: Timme Bisgaard Munk
# Inserted author name: Timnit Gebru
# Inserted author name: Timo Pykalainen
# Inserted author name: Timothy B Norris
# Inserted author name: Timothy Bowman
# Inserted author name: Timothy C Craven
# Inserted author name: Timothy Caulfield
# Inserted author name: Timothy Cole
# Inserted author name: Timothy Craven
# Inserted author name: Timothy D Bowman
# Inserted author name: Timothy Hale
# Inserted author name: Timothy J Hazen
# Inserted author name: Timothy M Hale
# Inserted author name: Timothy P Hogan
# Inserted author name: Timothy Thomas
# Inserted author name: Ting Luo
# Inserted author name: Tiziano Bonini
# Inserted author name: Tj Bliss
# Inserted author name: Tl Taylor
# Inserted author name: Tobias Raun
# Inserted author name: Toby Hopp
# Inserted author name: Todd Suomela
# Inserted author name: Tolga Aydin
# Inserted author name: Tom Barbereau
# Inserted author name: Tom Boellstorff
# Inserted author name: Tom Brock
# Inserted author name: Tom Cross
# Inserted author name: Tom Denison
# Inserted author name: Tom French
# Inserted author name: Tom Robertson
# Inserted author name: Tom Van Hout
# Inserted author name: Tom Willaert
# Inserted author name: Tomasz Drabowicz
# Inserted author name: Tomi Pasanen
# Inserted author name: Tommaso Venturini
# Inserted author name: Toni Carbo
# Inserted author name: Toni Rouhana
# Inserted author name: Tony Debons
# Inserted author name: Tony Gill
# Inserted author name: Tony Liao
# Inserted author name: Tony P Love
# Inserted author name: Tore Slaatta
# Inserted author name: Toufic Hakim
# Inserted author name: Travis Wall
# Inserted author name: Trebor Scholz
# Inserted author name: Trevor Pinch
# Inserted author name: Trevor Tompkins
# Inserted author name: Trond Andresen
# Inserted author name: Troy B Cooper
# Inserted author name: Troy Sadkowsky
# Inserted author name: Tsvi Kuflik
# Inserted author name: Ture Schwebs
# Inserted author name: Tyler Moore
# Inserted author name: Tze San Ong
# Inserted author name: Ulises Mejias
# Inserted author name: Ulrich Herb
# Inserted author name: Ulrich Norbisrath
# Inserted author name: Ulrich Riehm
# Inserted author name: Ulrik Jrgensen
# Inserted author name: Umashanthi Pavalanathan
# Inserted author name: Upol Ehsan
# Inserted author name: Ursula Gorham
# Inserted author name: Uzma Raja
# Inserted author name: Vaclav Stetka
# Inserted author name: Vadas Gintautas
# Inserted author name: Valdis Krebs
# Inserted author name: Valeria Arza
# Inserted author name: Valeria Ferrari
# Inserted author name: Valerie D Glenn
# Inserted author name: Valerie Drew
# Inserted author name: Valerie L Shalin
# Inserted author name: Valerie Schafer
# Inserted author name: Valerie Steeves
# Inserted author name: Valerie-Anne Bleyen
# Inserted author name: Vanessa Kitzie
# Inserted author name: Varada Kolhatkar
# Inserted author name: Varol Akman
# Inserted author name: Vasilis Kostakis
# Inserted author name: Veikko Eranti
# Inserted author name: Vera Buhlmann
# Inserted author name: Veronica B Pinero
# Inserted author name: Vesa Tienvieri
# Inserted author name: Vicki O'Day
# Inserted author name: Vicky Reich
# Inserted author name: Victor Bystrov
# Inserted author name: Victor Chahuneau
# Inserted author name: Victor Kaptelinin
# Inserted author name: Victor Sampson
# Inserted author name: Victoria A E Kratel
# Inserted author name: Victoria Kravchyna
# Inserted author name: Victoria L Rubin
# Inserted author name: Victoria Simon
# Inserted author name: Viivi Korpela
# Inserted author name: Vijay Pereira
# Inserted author name: Viktor Arvidsson
# Inserted author name: Viktor Chagas
# Inserted author name: Viktor Mayer-Schonberger
# Inserted author name: Viktoria Bruggemann
# Inserted author name: Vilde Schanke Sundet
# Inserted author name: Vincent Lariviere
# Inserted author name: Vincenzo D'Andrea
# Inserted author name: Vinicio Sinta
# Inserted author name: Viola Krebs
# Inserted author name: Vipul Ved Prakash
# Inserted author name: Virgilio Af Almeida
# Inserted author name: Virgilio Almeida
# Inserted author name: Virginia Kuhn
# Inserted author name: Vishal Uppala
# Inserted author name: Vittorio Mischi
# Inserted author name: Vivian Gerrand
# Inserted author name: Vivian Howard
# Inserted author name: Vivian Medina-Messner
# Inserted author name: Vivien Kg Lim
# Inserted author name: Vivienne Waller
# Inserted author name: Vlad Achimescu
# Inserted author name: Volodymyr Lysenko
# Inserted author name: Voula Lazarou
# Inserted author name: Vvs Raveendra
# Inserted author name: W K Hansen
# Inserted author name: W Mclaughlin
# Inserted author name: W Sean Mclaughlin
# Inserted author name: W Wayne Fu
# Inserted author name: Wael Salah Fahmi
# Inserted author name: Wagner James Au
# Inserted author name: Wai-Yin Ng
# Inserted author name: Walery Studennikov
# Inserted author name: Walid Magdy
# Inserted author name: Walt Scacchi
# Inserted author name: Walter Willinger
# Inserted author name: Wan-Zheng Ian
# Inserted author name: Wanda Katja Liebermann
# Inserted author name: Wannarat Natee
# Inserted author name: Ward Cates
# Inserted author name: Warren Thorngate
# Inserted author name: Wayne Buente
# Inserted author name: Weiai Wayne Xu
# Inserted author name: Weiqin Chen
# Inserted author name: Weiyu Zhang
# Inserted author name: Wendy Baird
# Inserted author name: Wendy Clark
# Inserted author name: Wenhong Chen
# Inserted author name: Wenzhao Tao
# Inserted author name: Wesley De Neve
# Inserted author name: Wesley Shrum
# Inserted author name: Whitney Phillips
# Inserted author name: Wiebke Loosen
# Inserted author name: Wilfred Dolfsma
# Inserted author name: Wilfred Owen Jr
# Inserted author name: Wilfried Daniels
# Inserted author name: Will Mari
# Inserted author name: William Allen
# Inserted author name: William Birdsall
# Inserted author name: William Butler O'Connor
# Inserted author name: William Caelli
# Inserted author name: William D Adler
# Inserted author name: William E Moen
# Inserted author name: William E White
# Inserted author name: William F Birdsall
# Inserted author name: William Foster
# Inserted author name: William H Allendorfer
# Inserted author name: William Hollingshead
# Inserted author name: William Howe
# Inserted author name: William Jones
# Inserted author name: William Mccallister
# Inserted author name: William Mchenry
# Inserted author name: William Mciver
# Inserted author name: William P Cassidy
# Inserted author name: William Penn
# Inserted author name: William T Howe
# Inserted author name: William W Cope
# Inserted author name: Willy Stastny
# Inserted author name: Wim Vanobberghen
# Inserted author name: Winnie Soon
# Inserted author name: Wolfgang Kaltenbrunner
# Inserted author name: Woodrow Hartzog
# Inserted author name: Wouter Joosen
# Inserted author name: Wujiong Ren
# Inserted author name: Wyatt Harrison
# Inserted author name: Xiao Wei
# Inserted author name: Xiaolong Jin
# Inserted author name: Xin Yu Ng
# Inserted author name: Xinning Gui
# Inserted author name: Xu Zhang
# Inserted author name: Yael Granot
# Inserted author name: Yaffa Aharoni
# Inserted author name: Yafit Lev-Aretz
# Inserted author name: Yan Jin
# Inserted author name: Yarden Skop
# Inserted author name: Yaretzi Campos
# Inserted author name: Yaron Ilan
# Inserted author name: Yashmeet Khopkar
# Inserted author name: Yasmin Ibrahim
# Inserted author name: Yee Man Margaret Ng
# Inserted author name: Yehuda E Kalay
# Inserted author name: Yeslam Al-Saggaf
# Inserted author name: Yi Zhang
# Inserted author name: Yiannis Mylonas
# Inserted author name: Yicheng Zhang
# Inserted author name: Yifat Mor
# Inserted author name: Yijun Gao
# Inserted author name: Yimei Zhu
# Inserted author name: Yiran Wang
# Inserted author name: Yngvar Kjus
# Inserted author name: Yong Hoe Hong
# Inserted author name: Yong Jin Park
# Inserted author name: Yong Ming Kow
# Inserted author name: Yong Zhao
# Inserted author name: Yong-Mi Kim
# Inserted author name: Yoshifumi Takayama
# Inserted author name: Younei Soe
# Inserted author name: Youngmin Jo
# Inserted author name: Yowei Kang
# Inserted author name: Ysabel Gerrard
# Inserted author name: Yu Bao
# Inserted author name: Yu Won Oh
# Inserted author name: Yu-Wen Chen
# Inserted author name: Yuan He
# Inserted author name: Yubo Kou
# Inserted author name: Yuchen Liu
# Inserted author name: Yuchen Zhou
# Inserted author name: Yue Ting Woo
# Inserted author name: Yuli Patrick Hsieh
# Inserted author name: Yulia Belinskaya
# Inserted author name: Yun Fu
# Inserted author name: Yun Wan
# Inserted author name: Yung-I Liu
# Inserted author name: Yuping Mao
# Inserted author name: Yuri Takhteyev
# Inserted author name: Yuwei Lin
# Inserted author name: Yuxian Eugene Liang
# Inserted author name: Yvette Knudtson
# Inserted author name: Zach Devereaux
# Inserted author name: Zachary O'Leary
# Inserted author name: Zack Lischer-Katz
# Inserted author name: Zak Muscovitch
# Inserted author name: Zelly Martin
# Inserted author name: Zeynep Tufekci
# Inserted author name: Zeyno Ustun
# Inserted author name: Zilia Estrada
# Inserted author name: Ziqian Song
# Inserted author name: Zizi Papacharissi
# Inserted author name: Zubair Nabi
